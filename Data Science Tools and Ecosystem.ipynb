# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# ## Introduction
#
# In this notebook, we will explore the essential tools and ecosystem that form the foundation of data science. We'll cover programming languages, libraries, development environments, and provide practical examples of basic operations commonly used in data science workflows.

# %% [markdown]
# ## Data Science Languages
#
# Some of the popular languages that Data Scientists use are:
#
# 1. **Python** - The most popular language for data science with extensive libraries
# 2. **R** - Specialized language for statistical computing and graphics
# 3. **SQL** - Essential for database querying and data manipulation
# 4. **Scala** - Used for big data processing with Apache Spark
# 5. **Java** - Popular for enterprise-level data science applications
# 6. **Julia** - High-performance language for numerical and scientific computing
# 7. **JavaScript** - Used for data visualization and web-based analytics
# 8. **MATLAB** - Widely used in academia and engineering for data analysis

# %% [markdown]
# ## Data Science Libraries
#
# Some of the commonly used libraries used by Data Scientists include:
#
# ### Python Libraries:
# - **Pandas** - Data manipulation and analysis
# - **NumPy** - Numerical computing and array operations
# - **Matplotlib** - Data visualization and plotting
# - **Seaborn** - Statistical data visualization
# - **Scikit-learn** - Machine learning algorithms
# - **TensorFlow** - Deep learning framework
# - **PyTorch** - Deep learning and neural networks
# - **Keras** - High-level neural networks API
#
# ### R Libraries:
# - **ggplot2** - Data visualization
# - **dplyr** - Data manipulation
# - **caret** - Classification and regression training
# - **randomForest** - Random forest algorithms

# %% [markdown]
# ## Data Science Tools
#
# | Category | Tools |
# |----------|--------|
# | **Development Environments** | Jupyter Notebook, RStudio, Spyder, PyCharm |
# | **Data Visualization** | Tableau, Power BI, Matplotlib, Plotly |
# | **Machine Learning Platforms** | TensorFlow, PyTorch, Scikit-learn, H2O.ai |
# | **Big Data Tools** | Apache Spark, Hadoop, Apache Kafka |
# | **Cloud Platforms** | AWS, Google Cloud Platform, Microsoft Azure |
# | **Version Control** | Git, GitHub, GitLab |
# | **Database Systems** | MySQL, PostgreSQL, MongoDB, SQLite |

# %% [markdown]
# ## Arithmetic Expression Examples
#
# Below are a few examples of evaluating arithmetic expressions in Python. These basic operations are fundamental in data science for calculations, transformations, and statistical computations.

# %%
# This is a simple arithmetic expression to multiply then add integers
result = (3 * 4) + 5
print(f"(3 * 4) + 5 = {result}")
# Out:
# (3 * 4) + 5 = 17

# %%
# This will convert 200 minutes to hours by dividing by 60
minutes = 200
hours = minutes / 60
print(f"{minutes} minutes is equal to {hours} hours")
# Out:
# 200 minutes is equal to 3.3333333333333335 hours

# %% [markdown]
# ## Objectives
#
# In this notebook, we covered the following key concepts and objectives:
#
# - List popular languages for Data Science
# - List commonly used libraries in Data Science
# - Understand the tools used in Data Science development environments
# - Perform basic arithmetic operations in Python
# - Convert time units using Python calculations
# - Create markdown documentation for data science projects
# - Share and collaborate using version control systems like GitHub

# %% [markdown]
# ## Author
#
# **Luis Fernando Arenas Yataco**
#
# _Data Science Enthusiast and Student_
